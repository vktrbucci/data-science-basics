# %% [markdown]
# # Visualização de Dados

# %% [markdown]
# ## Criando gráficos de linha

# %%
import pandas as pd

from matplotlib import pyplot as plt
from matplotlib import rcParams

import seaborn as sns

# %%
# Permite plotar gráficos dentro do notebook
# %matplotlib inline
# Definindo tamanho da figura em polegadas (altura x largura)
rcParams['figure.figsize'] = 5, 4 
sns.set_style('whitegrid')

# %% [markdown]
# ### Criando um gráfico de linha a partir de uma lista

# %% [markdown]
# #### Desenhando um gráfico de linha usando o matplotlib

# %%
x = range(1, 10)
y = [1, 2, 3, 4, 0, 4, 3, 2, 1]

plt.plot(x, y)

# %% [markdown]
# #### Desenhando um gráfico de linhas usando um objeto pandas

# %%
### TODO: Descolar um arquivo csv para testar essa célula
## Por enquanto essa célula não funciona, pois não temos um arquivo csv

# caminho = 'Arquivo csv mostrando dados de consumo de combustível de diversos veículos'

# # lendo o arquivo csv
# carros = pd.read_csv(caminho)
# # renomeando as colunas do dataset
# carros.columns = ['modelo', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'o resto']
# # selecionando as colunas para plotar no gráfico
# df = carros[['cyl', 'mpg', 'wt']]
# # método built-in do pandas para pltar gráficos
# df.plot()
